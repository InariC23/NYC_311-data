# %%
from google.colab import auth
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
import pandas
import google
from google.cloud import bigquery_storage
from google.cloud import bigquery

# %% [markdown]
# # **Data Exploration**

# %%
# %%bigquery --project capstone-project-347718
# SELECT
#   COUNT(*) as total_rows
# FROM `bigquery-public-data.new_york_311.311_service_requests`
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    total_rows
# 0    27039784

# %% [markdown]
# # **What are the most frequent 311 complaints in NYC?**

# %%
# %%bigquery --project capstone-project-347718
#
# WITH request_query
# AS
# (SELECT
#  created_date,
#  complaint_type,
#  agency,
#  borough,
#  EXTRACT(isoyear from created_date) as year
# FROM `bigquery-public-data.new_york_311.311_service_requests`)
#
# SELECT
#   complaint_type,
#   COUNT(complaint_type) AS `complaint_num`
# FROM request_query
# WHERE year >= 2019
# AND year <= 2021
# GROUP BY
# complaint_type
# ORDER BY
#   `complaint_num` DESC
# LIMIT 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             complaint_type  complaint_num
# 0      Noise - Residential         963948
# 1          Illegal Parking         658418
# 2           HEAT/HOT WATER         514353
# 3  Noise - Street/Sidewalk         479335
# 4         Blocked Driveway         382414
# 5         Street Condition         206724
# 6          Noise - Vehicle         202235
# 7   Street Light Condition         182084
# 8     UNSANITARY CONDITION         173410
# 9             Water System         150038

# %% [markdown]
# # **What are the least frequent 311 complaints in NYC?**

# %%
# %%bigquery --project capstone-project-347718
#
# WITH request_query
# AS
# (SELECT
#  created_date,
#  complaint_type,
#  agency,
#  borough,
#  EXTRACT(isoyear from created_date) as year
# FROM `bigquery-public-data.new_york_311.311_service_requests`)
#
# SELECT
#   complaint_type,
#   borough,
#   COUNT(complaint_type) AS `complaint_num`
# FROM requests_query
# WHERE year >= 2019
# AND year <= 2021
# GROUP BY
# complaint_type,borough
# HAVING `complaint_num` > 10
# ORDER BY
#   `complaint_num` ASC
#   LIMIT 15
# Out:
# ERROR:
#  ("Failed to retrieve http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/?recursive=true from the Google Compute Engine metadata service. Status: 404 Response:\nb''", <google.auth.transport.requests._Response object at 0x7f3a018f6160>)

# %% [markdown]
# # **Which Agency responds to the most requests?**
#
# ---

# %%
# %%bigquery --project capstone-project-347718
#
# WITH year_query
# AS
# (SELECT
#  created_date,
#  complaint_type,
#  agency,
#  borough,
#  EXTRACT(isoyear from created_date) as year
# FROM `bigquery-public-data.new_york_311.311_service_requests`)
#
# SELECT
#   complaint_type,
#   borough,
#   COUNT(complaint_type) AS `value_occurrence`
# FROM year_query
# WHERE year >= 2019
# AND year <= 2021
# GROUP BY
# complaint_type,borough
# ORDER BY
#   `value_occurrence` DESC;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                  complaint_type      borough  value_occurrence
# 0           Noise - Residential        BRONX            314993
# 1           Noise - Residential     BROOKLYN            244320
# 2               Illegal Parking     BROOKLYN            227223
# 3               Illegal Parking       QUEENS            211501
# 4           Noise - Residential       QUEENS            191589
# ...                         ...          ...               ...
# 1508               Construction       QUEENS                 1
# 1509           Outside Building     BROOKLYN                 1
# 1510                 Water Leak    MANHATTAN                 1
# 1511                   PLUMBING  Unspecified                 1
# 1512  Single Occupancy Bathroom        BRONX                 1
#
# [1513 rows x 3 columns]

# %% [markdown]
# # **What month & year has the most service requests ?**
#
# ---

# %%
# %%bigquery --project capstone-project-347718
# WITH month_query
# AS
# (SELECT
#  created_date,
#  complaint_type,
#  agency,
#  borough,
#  status,
#  EXTRACT(MONTH from created_date) as Month,
#  EXTRACT(isoyear from created_date) as year
# FROM `bigquery-public-data.new_york_311.311_service_requests`)
#
# SELECT
#   complaint_type,
#   borough,
#   COUNT(complaint_type) AS `value_occurrence`,
#   month_query.MONTH,
#   year
# FROM month_query
# WHERE year >= 2019
# AND year <= 2021
# GROUP BY
# complaint_type,borough,month_query.MONTH,year
# ORDER BY
#   `value_occurrence` DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                              complaint_type        borough  value_occurrence  \
# 0                       Noise - Residential          BRONX             24098
# 1                       Noise - Residential          BRONX             20907
# 2                              Damaged Tree         QUEENS             20315
# 3                       Noise - Residential          BRONX             20207
# 4                       Noise - Residential          BRONX             18893
# ...                                     ...            ...               ...
# 25464                        Borough Office  STATEN ISLAND                 1
# 25465   Investigations and Discipline (IAD)  STATEN ISLAND                 1
# 25466                       Scaffold Safety  STATEN ISLAND                 1
# 25467                        Found Property         QUEENS                 1
# 25468  Special Natural Area District (SNAD)         QUEENS                 1
#
#        MONTH  year
# 0          8  2020
# 1          9  2020
# 2          8  2020
# 3          7  2021
# 4          7  2020
# ...      ...   ...
# 25464      2  2020
# 25465      1  2020
# 25466      3  2020
# 25467      3  2020
# 25468      2  2020
#
# [25469 rows x 5 columns]

# %% [markdown]
# #**Which Borough has the highest complaints year by year?**
#
# ---

# %%
# %%bigquery --project capstone-project-347718
#
# WITH borough_query
# AS
# (SELECT
#  created_date,
#  complaint_type,
#  agency,
#  borough,
#  EXTRACT(isoyear from created_date) as year
# FROM `bigquery-public-data.new_york_311.311_service_requests`)
#
# SELECT
#   borough,
#   COUNT(complaint_type) AS `value_occurrence`,
#   year
# FROM borough_query
# WHERE year >= 2019
# AND year <= 2021
# GROUP BY
# borough,year
# ORDER BY `value_occurrence` DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#           borough  value_occurrence  year
# 0        BROOKLYN            751675  2019
# 1        BROOKLYN            739900  2020
# 2        BROOKLYN            677278  2021
# 3          QUEENS            604143  2020
# 4           BRONX            594084  2020
# 5          QUEENS            589397  2019
# 6          QUEENS            552604  2021
# 7       MANHATTAN            523418  2020
# 8           BRONX            518273  2021
# 9       MANHATTAN            488650  2021
# 10      MANHATTAN            475800  2019
# 11          BRONX            424282  2019
# 12  STATEN ISLAND            125630  2019
# 13  STATEN ISLAND            112269  2020
# 14  STATEN ISLAND            108513  2021
# 15           None             30733  2020
# 16    Unspecified             22105  2019
# 17    Unspecified             14082  2020
# 18    Unspecified              7871  2021
# 19           None              7338  2021
# 20           None              2069  2019

# %%
# %%bigquery --project capstone-project-347718
#
# WITH year_query
# AS
# (SELECT
#  created_date,
#  complaint_type,
#  agency,
#  borough,
#  EXTRACT(isoyear from created_date) as yearly
# FROM `bigquery-public-data.new_york_311.311_service_requests`)
# SELECT
#  yearly,
#  complaint_type,
#  agency,
#   COUNT (complaint_type) as type_count,
# FROM year_query
# WHERE borough = 'BROOKLYN'
# AND yearly >= 2019
# AND yearly <= 2022
# GROUP BY
#   complaint_type, agency,yearly
# ORDER BY type_count DESC, agency
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#      yearly             complaint_type agency  type_count
# 0      2020        Noise - Residential   NYPD       97007
# 1      2021            Illegal Parking   NYPD       91235
# 2      2021        Noise - Residential   NYPD       80292
# 3      2019            Illegal Parking   NYPD       69354
# 4      2019        Noise - Residential   NYPD       67020
# ..      ...                        ...    ...         ...
# 590    2020             Found Property    TLC           1
# 591    2021             Found Property    TLC           1
# 592    2019  Dispatched Taxi Complaint    TLC           1
# 593    2019            Taxi Compliment    TLC           1
# 594    2021          Green Taxi Report    TLC           1
#
# [595 rows x 4 columns]

# %% [markdown]
# # **Which agency responds to the Top 10 Complaints?**
#
# ---

# %%
# %%bigquery --project capstone-project-347718
# WITH year_query
# AS
# (SELECT
#  created_date,
#  complaint_type,
#  agency,
#  borough,
#  status,
#  EXTRACT(isoyear from created_date) as year
# FROM `bigquery-public-data.new_york_311.311_service_requests`)
#
# SELECT
#   complaint_type,
#   agency,
#   COUNT(complaint_type) AS `complaint_num`
# FROM year_query
# WHERE year >= 2019 AND year <= 2022
# GROUP BY
# complaint_type,agency
# ORDER BY
#   `complaint_num` DESC
#
# LIMIT 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#             complaint_type agency  complaint_num
# 0      Noise - Residential   NYPD         963946
# 1          Illegal Parking   NYPD         658418
# 2           HEAT/HOT WATER    HPD         514353
# 3  Noise - Street/Sidewalk   NYPD         479334
# 4         Blocked Driveway   NYPD         382414
# 5         Street Condition    DOT         206724
# 6          Noise - Vehicle   NYPD         202235
# 7   Street Light Condition    DOT         182084
# 8     UNSANITARY CONDITION    HPD         173410
# 9             Water System    DEP         150038

# %% [markdown]
# # **On average how many hours does it take for a agency to close a case?**

# %%
# %%bigquery --project capstone-project-347718
#
# WITH hour_query
# AS
# (SELECT
#  created_date,
#  complaint_type,
#  agency,
#  borough,
#  status,
#  EXTRACT(isoyear from created_date) as year,
#  TIMESTAMP_DIFF(closed_date, created_date, HOUR) as hours
# FROM `bigquery-public-data.new_york_311.311_service_requests`)
#
# SELECT
#   complaint_type,
#   agency,
#   status,
#   borough,
#   avg(hours) as hours,
#   COUNT(complaint_type) AS `value_occurrence`
# FROM hour_query
# WHERE year >= 2019
# AND year <= 2021 AND hours IS NOT NULL
# GROUP BY agency,status,borough,complaint_type
# ORDER BY
#   `value_occurrence` DESC
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#               complaint_type agency       status        borough         hours  \
# 0        Noise - Residential   NYPD       Closed          BRONX  1.180667e+01
# 1        Noise - Residential   NYPD       Closed       BROOKLYN  9.809180e+00
# 2            Illegal Parking   NYPD       Closed       BROOKLYN  5.888009e+00
# 3            Illegal Parking   NYPD       Closed         QUEENS  4.765510e+00
# 4        Noise - Residential   NYPD       Closed         QUEENS  2.897326e+00
# ...                      ...    ...          ...            ...           ...
# 1764     Hazardous Materials    DEP      Pending  STATEN ISLAND -1.187400e+04
# 1765              Mosquitoes  DOHMH       Closed    Unspecified  4.248000e+03
# 1766  Construction Lead Dust  DOHMH       Closed         QUEENS  1.720000e+02
# 1767                   Sewer    DEP      Started  STATEN ISLAND  5.500000e+01
# 1768    Non-Residential Heat  DOHMH  In Progress      MANHATTAN -1.060885e+06
#
#       value_occurrence
# 0               314982
# 1               244246
# 2               227205
# 3               211446
# 4               191461
# ...                ...
# 1764                 1
# 1765                 1
# 1766                 1
# 1767                 1
# 1768                 1
#
# [1769 rows x 6 columns]
